# %%
from dl_assignment_2.modeling.model import SimpleRNN
from dl_assignment_2.modeling.evaluation import Evaluator
from dl_assignment_2.modeling.dataset import TestDataset

from torch import nn, Tensor, tensor
from torch.utils.data import DataLoader
import numpy as np
from numpy import array, ndarray

from typing import Callable

# %%
# 5 instances of 3 features
x: Tensor = tensor(range(1,16)).reshape((3,5))
y: Tensor = tensor([0,1,0,2])

dl = DataLoader(TestDataset(x, y))

model = SimpleRNN(5, 10, 4)
# Out:
# /home/alex/Documents/master/period_4/DL/DL_assignment_2/src/dl_assignment_2/modeling/dataset.py:48: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = tensor(y).to(float32)

# %%
eval = Evaluator(model, dl)

# %%
for x, y in dl:
    y = model(x)
    print(y)
# Out:
# tensor([[[ 1.0065,  0.1712, -0.5101, -1.1849]]], grad_fn=<ViewBackward0>)
