# %%
from dl_assignment_2.analysis.task_level.betweenTaskAnalysis import BetweenTaskAnalysis

bta = BetweenTaskAnalysis(wanted_segment=1)
bta.trim(100)
bta.transform()
bta.summarize()
#bta.plot()
#bta.plot(way="hist")
bta.plot(way="lines")
print("\n\n")

bta.get_residuals()
bta.summarize()
bta.plot()
bta.plot(way="hist")

print(type(bta.task_to_segment["rest"]))
# Out:
# task_motor           w. mean: -0.029201572731211437, max: 7.170371935094622, min: -128.60847109497087
# task_story_math      w. mean: 0.8467636602635464, max: 8.08638139088158, min: -65.55506831817937
# rest                 w. mean: 0.04070915678984937, max: 12.630678621061708, min: -26.84950699272104
# task_working_memory  w. mean: 0.3862341505012545, max: 11.248300034460978, min: -96.52244975510982
# task_motor           w. mean: -0.0016062986927334558, max: 2.589407854802772, min: -2.812985955280567
# task_story_math      w. mean: 0.0008460143628500676, max: 2.549983986986637, min: -2.7685995653719577
# rest                 w. mean: 0.002455559874491488, max: 2.586232118219345, min: -2.479512837996571
# task_working_memory  w. mean: 0.0006484700168641333, max: 2.6176386362306014, min: -3.077097170817167
# <class 'dl_assignment_2.data.residualSegment.ResidualSegment'>

# %%
bta = BetweenTaskAnalysis(wanted_segment=2)
bta.trim(100)
bta.transform()
bta.summarize()
#bta.plot()
#bta.plot(way="hist")
bta.plot(way="lines")
print("\n\n")

bta.get_residuals()
bta.summarize()
bta.plot()
bta.plot(way="hist")

print(type(bta.task_to_segment["rest"]))
# Out:
# task_motor           w. mean: -0.1647004481952376, max: 6.648384100194082, min: -142.8311219298095
# task_story_math      w. mean: 0.831086952266602, max: 8.750304300586542, min: -78.28457326830573
# rest                 w. mean: 1.0319699158321185, max: 15.636219749537439, min: -42.35690964637939
# task_working_memory  w. mean: 0.9310847264609688, max: 12.720170403102138, min: -115.60549739719761
# task_motor           w. mean: 6.476232152827163e-05, max: 3.379699298200478, min: -4.024017230541688
# task_story_math      w. mean: -0.0005052036700590872, max: 2.392323318611833, min: -2.6889543109503977
# rest                 w. mean: 0.0010999403134177793, max: 2.817123921292075, min: -33.83309648066768
# task_working_memory  w. mean: 0.0015375264311634053, max: 2.911031658781038, min: -2.5886237597916306
# <class 'dl_assignment_2.data.residualSegment.ResidualSegment'>

# %%
bta = BetweenTaskAnalysis(wanted_segment=3)
bta.trim(100)
bta.transform()
bta.summarize()
#bta.plot()
#bta.plot(way="hist")
bta.plot(way="lines")
bta.plot(way="hist")
print("\n\n")

bta.get_residuals()
bta.summarize()
bta.plot()
bta.plot(way="hist")

print(type(bta.task_to_segment["rest"]))
# Out:
# rest                 w. mean: 1.0044611898591045, max: 18.146349006764595, min: -44.044049657410156
# task_working_memory  w. mean: 1.0144931285038228, max: 13.194168847763255, min: -124.41060681656069
# task_story_math      w. mean: 1.0132758779877455, max: 7.750464332823004, min: -83.56619562999157
# task_motor           w. mean: -0.3142071240954029, max: 8.081718454178155, min: -160.8793376295381
# rest                 w. mean: -0.0008049747291144441, max: 3.449588054441066, min: -3.436134840203997
# task_working_memory  w. mean: 0.0004763077348909441, max: 2.424366480138773, min: -2.9908463943309482
# task_story_math      w. mean: 0.001181746258519645, max: 3.104182058968896, min: -2.824337985707359
# task_motor           w. mean: 0.0004986162389110314, max: 3.034683615510403, min: -3.1111502263314605
# <class 'dl_assignment_2.data.residualSegment.ResidualSegment'>
